# %% [markdown]
# # nolta2022
#
# This notebook shows how to run the source codes used in the following work:
#
# * Makito Oku: "Estimation of the critical transition probability using quadratic polynomial approximation with skewness-based reject option", NOLTA, submitted.
#
# All the source files are in the `scripts` directory. The random number seed is not fixed for technical reasons, so the results may vary slightly each time the codes are run.

# %% [markdown]
# ## Initial settings

# %%
# %cd /content/
# !rm -rf nolta2022
# !git clone https://github.com/okumakito/nolta2022
# %cd ./nolta2022/scripts
# %run -i functions.py
plt.plot(); plt.close() # I don't know why but this line is needed to show inline figures at least in my environment.
# Out:
# /content
# Cloning into 'nolta2022'...
# remote: Enumerating objects: 71, done.
# remote: Counting objects: 100% (71/71), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 71 (delta 29), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (71/71), done.
# /content/nolta2022/scripts

# %% [markdown]
# ## Figure 1

# %%
# %run -i plot_trans.py

# %% [markdown]
# ## Figure 2

# %%
# %run -i plot_trans_type.py

# %% [markdown]
# ## Figure 3

# %%
# %run -i plot_upf.py

# %% [markdown]
# ## Figure 4

# %%
# %run -i plot_phase.py

# %% [markdown]
# ## Figure 5

# %%
# %run -i plot_bifurc.py

# %% [markdown]
# ## Figure 6

# %%
# %run -i plot_flow.py

# %% [markdown]
# ## Figure 7

# %%
# %run -i plot_potential.py

# %% [markdown]
# ## Figure 8

# %%
# %run -i loop_dist.py
# %run -i plot_dist.py

# %% [markdown]
# ## Figure 9
# about 5 min

# %%
# %run -i loop_prob.py
# %run -i plot_prob.py
# Out:
# time = 234.303s
# T (theory)    = 1.31e+04
# T (numerical) = 1.38e+04

# %% [markdown]
# ## Figure 10

# %%
# %run -i loop_skew.py
# %run -i plot_skew.py
# Out:
# time = 23.6426 s
# -0.5         skew_val
# n
# 1000       0.142
# 10000      0.269
# 100000     0.234
# -0.4         skew_val
# n
# 1000       0.210
# 10000      0.398
# 100000     0.624

# %% [markdown]
# ## Figure 11
# about 30 min

# %%
# %run -i loop_mae.py skew lsm
res_mae_f = result_df
# %run -i loop_mae.py skew mle
res_mae_u = result_df
# %run -i plot_mae2.py skew
# Out:
# time = 555.541 s
# time = 1306.17 s
# n
# $N=10^3$    1.331
# $N=10^4$    0.851
# $N=10^5$    0.568
# Name: error, dtype: float64
# n
# $N=10^3$    1.205
# $N=10^4$    0.820
# $N=10^5$    0.591
# Name: error, dtype: float64

# %% [markdown]
# ## Figure 12
# about 30 min

# %%
# %run -i loop_mae.py skip lsm
res_mae_f = result_df
# %run -i loop_mae.py skip mle
res_mae_u = result_df
# %run -i plot_mae2.py skip
# Out:
# time = 759.729 s
# time = 823.217 s
# n
# $N=10^3$    1.745
# $N=10^4$    1.109
# $N=10^5$    0.639
# Name: error, dtype: float64
# n
# $N=10^3$    1.015
# $N=10^4$    0.561
# $N=10^5$    0.416
# Name: error, dtype: float64
